# %% [markdown]
# ### Topic 1 Challenge
# Write a function `report_line(label, value)` that **returns** a string shaped like `"  Used       :      87.00"` (right-aligned, 2 decimal places). Use it three times to print three lines of a report.

# %%
# your code here
