# %% [markdown]
# ### Same idea, three fields — worked examples
# A variable holds one fact about one thing. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
reading = 23.7
units = "celsius"
print(reading, units)

# %% [markdown]
# **Cyber Security**

# %%
source_ip = "10.0.0.5"
port = 443
print(source_ip, port)

# %% [markdown]
# **IT**

# %%
hostname = "srv-01"
disk_used = 87
print(hostname, disk_used)
