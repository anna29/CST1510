# %% [markdown]
# ### Practice
# This cell writes `my_notes.txt` for you again. Read it line by line and print each line, stripped.

# %%
with open("my_notes.txt", "w") as f:
    f.write("first note\n")
    f.write("second note\n")
    f.write("third note\n")

# your code here
