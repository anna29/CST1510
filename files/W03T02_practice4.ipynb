# %% [markdown]
# ### Practice
# Write `connect(host, port=443, timeout=30)` (it can just `return` a description string) and call it three ways: all positional, all keyword, and mixed.

# %%
# your code here
