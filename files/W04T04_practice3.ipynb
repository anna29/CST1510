# %% [markdown]
# ### Practice
# Given `entries = [{"label": "E-01", "value": 95.0, "limit": 90.0}, {"label": "E-02", "value": 40.0, "limit": 90.0}]`, loop through it and print `OVER LIMIT` or `OK` for each.

# %%
entries = [
    {"label": "E-01", "value": 95.0, "limit": 90.0},
    {"label": "E-02", "value": 40.0, "limit": 90.0},
]

# your code here
