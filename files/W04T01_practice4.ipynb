# %% [markdown]
# ### Practice
# Given `hosts = ["srv-01", "srv-02", "srv-03"]`: append `"srv-04"`, remove `"srv-02"`, then loop over what is left and print each value.

# %%
hosts = ["srv-01", "srv-02", "srv-03"]

# your code here
