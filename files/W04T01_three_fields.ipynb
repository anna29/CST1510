# %% [markdown]
# ### Same idea, three fields — worked examples
# A list of readings from one sensor, one hour, one night's checklist. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
sensor_readings = [21.4, 21.9, 22.0, 21.7]
print(sensor_readings)
print(sensor_readings[-1])

# %% [markdown]
# **Cyber Security**

# %%
failed_logins = ["10.0.0.5", "10.0.0.9", "10.0.0.5"]
print(failed_logins)
print(len(failed_logins))

# %% [markdown]
# **IT**

# %%
due_tonight = ["srv-01", "srv-03", "srv-07"]
print(due_tonight)
for host in due_tonight:
    print(f"check {host}")
