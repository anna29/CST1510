# %% [markdown]
# ### Topic 1 Challenge
# Given `readings = [87, 120, 45, 93, 101]` and a fixed `limit = 100`, loop over the list and print `OVER LIMIT` or `OK` for each value.

# %%
readings = [87, 120, 45, 93, 101]
limit = 100

# your code here
