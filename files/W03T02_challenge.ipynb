# %% [markdown]
# ### Topic 2 Challenge
# Write `status_of(value, limit, warning_at=90)` — note the change from Topic 1: it now takes `value` and `limit` directly and works out the percentage itself, instead of being handed a percentage. Test it with `warning_at` left at its default, and again overridden to `95`.

# %%
# your code here
