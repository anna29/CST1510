# %% [markdown]
# ### Topic 2 Challenge
# Add `percent(self)` and `status(self)` to your `Record` class from Topic 1. `status()` should call `self.percent()`, not recalculate it. Test it on two different instances.

# %%
class Record:
    def __init__(self, label, value, limit):
        self.label = label
        self.value = value
        self.limit = limit

    def summary(self):
        return f"{self.label}: {self.value}/{self.limit}"

# %%
# your code here
