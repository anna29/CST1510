# %% [markdown]
# ### Topic 1 Challenge
# Given `attempts = 4` and `max_attempts = 3`, store whether the account should be locked in a variable called `locked` (`attempts` at or over `max_attempts`), then print:
#
# ```
# Locked: True
# ```
#
# using an f-string.

# %%
attempts = 4
max_attempts = 3

# your code here
