# %% [markdown]
# ### Topic 3 Challenge
# Write a function `load_records(path)` that reads a file of `label,value,limit` lines and returns a list of dicts — one dict per line, shaped like `{"label": ..., "value": ..., "limit": ...}`. Write a small file of your own to test it on.

# %%
# your code here
