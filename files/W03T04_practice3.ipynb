# %% [markdown]
# ### Practice
# Rewrite this using `from math import sqrt, pow` instead of `import math`:
#
# ```python
# import math
# print(math.sqrt(81))
# print(math.pow(2, 5))
# ```

# %%
import math
print(math.sqrt(81))
print(math.pow(2, 5))

# your code here
