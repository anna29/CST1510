# %% [markdown]
# ### Topic 2 Challenge
# A login has `failed_attempts` and a limit of 3. Print `LOCKED` if at or over the limit, `WARNING` if exactly one below it, otherwise `OK`. Test it with `failed_attempts` set to 1, 2 and 3 — change the value below and re-run.

# %%
failed_attempts = 2

# your code here
