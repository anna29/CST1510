# %% [markdown]
# ### Practice
# This function has no default value:
#
# ```python
# def greeting(name, punctuation):
#     return f"Hello, {name}{punctuation}"
# ```
#
# Give `punctuation` a default value of `"!"`, then call it once leaving `punctuation` out and once overriding it.

# %%
def greeting(name, punctuation):
    return f"Hello, {name}{punctuation}"

# your code here
