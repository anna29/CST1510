# %% [markdown]
# ### Topic 4 Challenge
# Using `random`, simulate checking 5 records against a fixed `limit = 100`. For each one, generate a random `value` with `random.randint(50, 150)`, then print whether it is `OVER LIMIT` or `OK`. Reuse the `status_of` function below — do not write the decision logic twice.

# %%
import random

def status_of(value, limit):
    return "OVER LIMIT" if value > limit else "OK"

limit = 100

# your code here
