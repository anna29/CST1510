# %% [markdown]
# ### Topic 4 Challenge
# Write `load_records(path)`, load records from a file of your own, process each one (`OVER LIMIT` / `WARNING` / `OK`), and print a summary line: `"N of M were over limit"`.

# %%
# your code here
