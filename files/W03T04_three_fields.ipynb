# %% [markdown]
# ### Same idea, three fields — worked examples
# A module is just wiring someone else already built, that you get to reuse. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
import statistics

values = [87, 92, 78, 95]
print(statistics.mean(values))
print(statistics.median(values))

# %% [markdown]
# **Cyber Security**

# %%
import hashlib

password = "python123"
print(hashlib.sha256(password.encode()).hexdigest())

# %% [markdown]
# **IT**

# %%
import datetime

today = datetime.date(2026, 9, 9)
print(f"Log entry: {today}")
