# %% [markdown]
# ### Practice
# The next cell has three bad names. Rewrite it with good ones. The output should not change.

# %%
x = "srv-01"
y = 87
z = 100
print(x, y, z)

# %%
# your rewrite here
