# %% [markdown]
# ### Practice
# Use `.get()` on `host` to safely check for a key you know does not exist, with a default of your choosing.

# %%
host = {"name": "srv-05", "used_gb": 40, "total_gb": 80}

# your code here
