# %% [markdown]
# ### Same idea, three fields — worked examples
# A comparison is the universal *"does this cross a line?"* check. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
missing_pct = 7.5
print(missing_pct > 5)

# %% [markdown]
# **Cyber Security**

# %%
failed_logins = 3
print(failed_logins >= 3)

# %% [markdown]
# **IT**

# %%
disk_used_pct = 92
print(disk_used_pct >= 90)
