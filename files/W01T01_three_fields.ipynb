# %% [markdown]
# ### Same idea, three fields — worked examples
# `print()` is how a program reports what it found. Same tool, different job. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
print("Rows loaded: 1200")

# %% [markdown]
# **Cyber Security**

# %%
print("[ALERT] failed login from 10.0.0.5")

# %% [markdown]
# **IT**

# %%
print("Backup complete - 4 of 4 servers")
