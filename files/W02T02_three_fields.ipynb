# %% [markdown]
# ### Same idea, three fields — worked examples
# Booleans decide something is true — this is where the program acts on it. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
missing_pct = 7.5
if missing_pct > 5:
    print("check pipeline")

# %% [markdown]
# **Cyber Security**

# %%
failed_logins = 4
if failed_logins >= 3:
    print("LOCKED")

# %% [markdown]
# **IT**

# %%
disk_used_pct = 92
if disk_used_pct >= 90:
    print("ALERT")
