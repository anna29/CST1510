# %% [markdown]
# ### Practice
# Save 3 `label,value,limit` lines of your own to a file, then load them with `load_records`.

# %%
def load_records(path):
    """Read label,value,limit lines from a file and return a list of dicts."""
    records = []
    with open(path) as f:
        for line in f:
            label, value, limit = line.strip().split(",")
            records.append({"label": label, "value": float(value), "limit": float(limit)})
    return records

# your code here
