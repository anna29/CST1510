# %% [markdown]
# ### Practice
# This function works but has no docstring:
#
# ```python
# def double(n):
#     return n * 2
# ```
#
# Add a one-line docstring describing what it does, then run `help(double)` to see it.

# %%
def double(n):
    return n * 2

# your code here
