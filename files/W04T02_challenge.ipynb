# %% [markdown]
# ### Topic 2 Challenge
# Given `disk = {"used": 87.0, "total": 120.0, "free": 33.0}`, print a formatted report line for each key-value pair, right-aligning the values, using `.items()`.

# %%
disk = {"used": 87.0, "total": 120.0, "free": 33.0}

# your code here
