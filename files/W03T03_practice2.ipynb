# %% [markdown]
# ### Practice
# Given `def triple(n):\n    n = n * 3\n    return n` and `total = 10`, predict then check: after `triple(total)` runs, is `total` `30` or still `10`?

# %%
def triple(n):
    n = n * 3
    return n

total = 10

# your code here
