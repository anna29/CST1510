# %% [markdown]
# ### Practice
# Given this function:
#
# ```python
# def describe(host, port):
#     return f"{host}:{port}"
# ```
#
# call it using keyword arguments, in the opposite order to how it was defined.

# %%
def describe(host, port):
    return f"{host}:{port}"

# your code here
