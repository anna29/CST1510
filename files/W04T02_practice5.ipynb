# %% [markdown]
# ### Practice
# Given `visited_hosts = ["srv-01", "srv-02", "srv-01", "srv-03", "srv-02"]`, use a set to find out how many unique values it contains.

# %%
visited_hosts = ["srv-01", "srv-02", "srv-01", "srv-03", "srv-02"]

# your code here
