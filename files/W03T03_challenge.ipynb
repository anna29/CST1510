# %% [markdown]
# ### Topic 3 Challenge
# This is broken — it expects `status` to update outside the function:
#
# ```python
# def check(value, limit):
#     status = "OVER LIMIT" if value > limit else "OK"
#
# check(87, 100)
# print(status)
# ```
#
# Fix it using `return`, without using anything you have not been taught yet.

# %%
def check(value, limit):
    status = "OVER LIMIT" if value > limit else "OK"

check(87, 100)
# print(status)  # NameError - fix below

# your code here
