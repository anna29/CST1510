# %% [markdown]
# ### Same idea, three fields — worked examples
# Ask for something, convert it, report it back cleanly. Run each cell.

# %% [markdown]
# **AI / Data Science**

# %%
mean = 23.6789
n = 1200
print(f"Mean: {mean:.2f} over {n} rows")

# %% [markdown]
# **Cyber Security**

# %%
level = "WARNING"
failed = 7
ip = "10.0.0.5"
print(f"[{level}] {failed} failed logins from {ip}")

# %% [markdown]
# **IT**

# %%
hostname = "srv-01"
used = 87
print(f"{hostname:<12} disk {used:>3} %")
