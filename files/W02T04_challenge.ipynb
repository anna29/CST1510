# %% [markdown]
# ### Topic 4 Challenge
# Ask for and check exactly 5 records in one run, using a `for` loop. For each one, print whether it is `OVER LIMIT` or `OK` — reuse your `if` / `else` from Topic 2. Use a fixed `limit = 100` for every record.

# %%
limit = 100

# your code here
